# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data\miscellaneous\Electric 3-Wheeler Sales.csv")

# %%
df.head()
# Out:
#            type financial_year month  num_vehicles
# 0  E-3 Wheelers        2017-18   Apr          4748
# 1  E-3 Wheelers        2017-18   May          6720
# 2  E-3 Wheelers        2017-18   Jun          7178
# 3  E-3 Wheelers        2017-18   Jul          8775
# 4  E-3 Wheelers        2017-18   Aug          8905

# %%
df['date'] = pd.to_datetime(df['financial_year'].str[:4] + '-' + df['month'], format='%Y-%b')

# Aggregate number of vehicles per month across all financial years
monthly_data = df.groupby('date')['num_vehicles'].sum()

plt.plot(monthly_data.index, monthly_data.values, linestyle='-')

plt.xlabel('Month')
plt.ylabel('Number of 3-Wheelers')
plt.title('Number of Units Sold Over Time')

plt.xticks(rotation=45)

plt.grid(True)  
plt.tight_layout()  
plt.show()
